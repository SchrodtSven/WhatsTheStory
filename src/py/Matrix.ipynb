# %% [markdown]
# # Matrix, Grid, 2d Array

# %%
# Defining number of rows and columns in matrix
rows = 3
cols = 3

# Declaring a matrix of size 3 X 3, and 
# initializing it with value one
rows, cols = (3, 3)
arr = [[1]*cols]*rows
print(arr)
# Out:
# [[1, 1, 1], [1, 1, 1], [1, 1, 1]]
